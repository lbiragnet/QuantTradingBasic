# %%
from option_pricing_black_scholes import *

# Setup option
S0 = 100
K = 95
r = .0
q = .0
T0 = .25
sigma0 = .4
Type = "Put"
dt = 1 / 252
option = BlackScholesEuropeanOption(S0, K, T0, r, sigma0, Type, q)

# Decompose P&L
x, y = greeks_pnl_decomposition(option, dt, .6, .1, 0, 1)

# Plot P&L decomposition
fig = plt.figure(figsize=(15, 5))
plt.bar(x, y)
plt.title("P&L Decomposition")
plt.show()
# Out:
# P&L: 1.9547849327324118
